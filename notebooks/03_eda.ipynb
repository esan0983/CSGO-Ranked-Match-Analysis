# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data/processed/csgo_cleaned_2.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 864980 entries, 0 to 864979
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       864980 non-null  int64
#  1   file             864980 non-null  str
#  2   map              864980 non-null  str
#  3   date             864980 non-null  str
#  4   round            864980 non-null  int64
#  5   tick             864980 non-null  int64
#  6   seconds          864980 non-null  float64
#  7   att_team         864980 non-null  str
#  8   vic_team         864980 non-null  str
#  9   att_side         864980 non-null  str
#  10  vic_side         864980 non-null  str
#  11  hp_dmg           864980 non-null  int64
#  12  arm_dmg          864980 non-null  int64
#  13  is_bomb_planted  864980 non-null  bool
#  14  bomb_site        133956 non-null  str
#  15  hitbox           864980 non-null  str
#  16  wp               864980 non-null  str
#  17  wp_type          864980 non-null  str
#  18  award            864980 non-null  int64
#  19  winner_team      864980 non-null  str
#  20  winner_side      864980 non-null  str
#  21  att_id           864980 non-null  int64
#  22  att_rank         864980 non-null  int64
#  23  vic_id           864980 non-null  int64
#  24  vic_rank         864980 non-null  int64
#  25  att_pos_x        864980 non-null  float64
#  26  att_pos_y        864980 non-null  float64
#  27  vic_pos_x        864980 non-null  float64
#  28  vic_pos_y        864980 non-null  float64
#  29  round_type       864980 non-null  str
#  30  ct_eq_val        864980 non-null  int64
#  31  t_eq_val         864980 non-null  int64
#  32  avg_match_rank   864980 non-null  float64
#  33  map_1            864980 non-null  str
#  34  EndX             864980 non-null  int64
#  35  EndY             864980 non-null  int64
#  36  ResX             864980 non-null  int64
#  37  ResY             864980 non-null  int64
#  38  StartX           864980 non-null  int64
#  39  StartY           864980 non-null  int64
# dtypes: bool(1), float64(6), int64(18), str(15)
# memory usage: 258.2 MB

# %%
df["map"].value_counts().plot(kind="bar")
plt.title('Map Counts')
plt.xlabel('Map')
plt.ylabel('Count')
plt.savefig("../images/03_map_counts.png")
plt.show()

# %%
round_counts = df["round"].value_counts()
round_counts.sort_index().plot(kind='bar')
plt.xlabel('Round')
plt.ylabel('Counts')
plt.title('Round Counts')
plt.savefig("../images/03_round_counts.png")
plt.show()

# %%
plt.boxplot(df["tick"])
plt.title("Ticks")
plt.savefig("../images/03_ticks.png")
plt.show()

# %%
plt.boxplot(df["seconds"])
plt.title("Seconds")
plt.savefig("../images/03_seconds.png")
plt.show()

# %%
plt.boxplot(df["arm_dmg"])
plt.title("Armor Damage")
plt.savefig("../images/03_arm_dmg.png")
plt.show()

# %%
plt.boxplot(df["hp_dmg"])
plt.title("HP Damage")
plt.savefig("../images/03_hp_dmg.png")
plt.show()

# %%
df["is_bomb_planted"].value_counts().plot(kind="bar")
plt.title('Is bomb planted?')
plt.xlabel('True/False')
plt.ylabel('Count')
plt.savefig("../images/03_bomb_counts.png")
plt.show()

# %%
temp_df = df.loc[df["is_bomb_planted"] == True, "bomb_site"]
temp_df.value_counts().plot(kind="bar")
plt.title('Bomb Site Counts')
plt.xlabel('Bomb Site')
plt.ylabel('Count')
plt.savefig("../images/03_bomb_site_counts.png")
plt.show()

# %%
df["hitbox"].value_counts().plot(kind="bar")
plt.title('Hitbox Counts')
plt.xlabel('Hitbox')
plt.ylabel('Count')
plt.savefig("../images/03_hitbox_counts.png")
plt.show()

# %%
df["wp"].value_counts().plot(kind="bar")
plt.title('Weapon Counts')
plt.xlabel('Weapon')
plt.ylabel('Count')
plt.savefig("../images/03_wp_counts.png")
plt.show()

# %%
df["wp_type"].value_counts().plot(kind="bar")
plt.title('Weapon Type Counts')
plt.xlabel('Weapon Type')
plt.ylabel('Count')
plt.savefig("../images/03_wp_type_counts.png")
plt.show()

# %%
att_rank_counts = df["att_rank"].value_counts()
att_rank_counts.sort_index().plot(kind='bar')
plt.xlabel('Attacker Rank')
plt.ylabel('Counts')
plt.title('Attacker Rank Counts')
plt.savefig("../images/03_att_rank_counts.png")
plt.show()

# %%
vic_rank_counts = df["vic_rank"].value_counts()
vic_rank_counts.sort_index().plot(kind='bar')
plt.xlabel('Victim Rank')
plt.ylabel('Counts')
plt.title('Victim Rank Counts')
plt.savefig("../images/03_vic_rank_counts.png")
plt.show()

# %%
df["round_type"].value_counts().plot(kind="bar")
plt.title('Round Type Counts')
plt.xlabel('Round Type')
plt.ylabel('Count')
plt.savefig("../images/03_round_type_counts.png")
plt.show()

# %%
avg_rank_counts = df["avg_match_rank"].value_counts()
avg_rank_counts.sort_index().plot(kind='bar')
plt.xlabel('Average Match Rank')
plt.ylabel('Counts')
plt.title('Average Match Rank Counts')
plt.savefig("../images/03_avg_rank_counts.png")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 864980 entries, 0 to 864979
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       864980 non-null  int64
#  1   file             864980 non-null  str
#  2   map              864980 non-null  str
#  3   date             864980 non-null  str
#  4   round            864980 non-null  int64
#  5   tick             864980 non-null  int64
#  6   seconds          864980 non-null  float64
#  7   att_team         864980 non-null  str
#  8   vic_team         864980 non-null  str
#  9   att_side         864980 non-null  str
#  10  vic_side         864980 non-null  str
#  11  hp_dmg           864980 non-null  int64
#  12  arm_dmg          864980 non-null  int64
#  13  is_bomb_planted  864980 non-null  bool
#  14  bomb_site        133956 non-null  str
#  15  hitbox           864980 non-null  str
#  16  wp               864980 non-null  str
#  17  wp_type          864980 non-null  str
#  18  award            864980 non-null  int64
#  19  winner_team      864980 non-null  str
#  20  winner_side      864980 non-null  str
#  21  att_id           864980 non-null  int64
#  22  att_rank         864980 non-null  int64
#  23  vic_id           864980 non-null  int64
#  24  vic_rank         864980 non-null  int64
#  25  att_pos_x        864980 non-null  float64
#  26  att_pos_y        864980 non-null  float64
#  27  vic_pos_x        864980 non-null  float64
#  28  vic_pos_y        864980 non-null  float64
#  29  round_type       864980 non-null  str
#  30  ct_eq_val        864980 non-null  int64
#  31  t_eq_val         864980 non-null  int64
#  32  avg_match_rank   864980 non-null  float64
#  33  map_1            864980 non-null  str
#  34  EndX             864980 non-null  int64
#  35  EndY             864980 non-null  int64
#  36  ResX             864980 non-null  int64
#  37  ResY             864980 non-null  int64
#  38  StartX           864980 non-null  int64
#  39  StartY           864980 non-null  int64
# dtypes: bool(1), float64(6), int64(18), str(15)
# memory usage: 258.2 MB

# %%
# plt.hist(df.loc[df["wp_type"] == "Rifle", "hp_dmg"])
# plt.xlabel('HP Damage')
# plt.ylabel('Counts')
# plt.title('HP Damage Counts (Rifle)')
# plt.show()

# %%
headshot_percentages = (df['hitbox'] == 'Head').groupby(df['att_rank']).mean() * 100
headshot_percentages
X = sorted(df["att_rank"].unique())
print(X)
print(headshot_percentages)
plt.xlabel('Attacker Rank')
plt.ylabel('Headshot %')
plt.title('Headshot Percentage by Rank')
plt.savefig("../images/03_headshot_percentages.png")

plt.plot(X, headshot_percentages)
# Out:
# [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18)]
# att_rank
# 1      6.944444
# 2     11.221945
# 3      7.301587
# 4     10.839532
# 5      8.675125
# 6      9.106004
# 7     10.372155
# 8     10.466025
# 9     10.759868
# 10    10.847402
# 11    11.239526
# 12    12.103734
# 13    12.831916
# 14    13.036692
# 15    14.056686
# 16    14.335739
# 17    14.943363
# 18    19.250646
# Name: hitbox, dtype: float64

# %%
pd.crosstab(df["hitbox"], df["wp_type"], normalize=1)
# Out:
# wp_type   Equipment  Grenade     Heavy    Pistol     Rifle       SMG  \
# hitbox
# Chest           0.0      0.0  0.433439  0.478738  0.419891  0.422789
# Generic         1.0      1.0  0.000000  0.000176  0.000049  0.000098
# Head            0.0      0.0  0.106329  0.186811  0.117442  0.108491
# LeftArm         0.0      0.0  0.035285  0.026605  0.030597  0.032998
# LeftLeg         0.0      0.0  0.048312  0.030807  0.049623  0.055557
# RightArm        0.0      0.0  0.085970  0.076109  0.079135  0.077570
# RightLeg        0.0      0.0  0.053956  0.033745  0.054274  0.056823
# Stomach         0.0      0.0  0.236709  0.167009  0.248987  0.245673
#
# wp_type     Sniper  Unknown
# hitbox
# Chest     0.512965      0.0
# Generic   0.000065      1.0
# Head      0.115739      0.0
# LeftArm   0.028700      0.0
# LeftLeg   0.023314      0.0
# RightArm  0.090376      0.0
# RightLeg  0.026301      0.0
# Stomach   0.202539      0.0

# %%
pd.crosstab(df["att_rank"], df["wp_type"], normalize=0)
# Out:
# wp_type   Equipment   Grenade     Heavy    Pistol     Rifle       SMG  \
# att_rank
# 1          0.013889  0.000000  0.000000  0.201389  0.319444  0.458333
# 2          0.000000  0.022444  0.014963  0.206983  0.483791  0.226933
# 3          0.001587  0.049206  0.009524  0.241270  0.422222  0.266667
# 4          0.001063  0.036132  0.072264  0.212540  0.452710  0.193411
# 5          0.002066  0.076129  0.016524  0.182355  0.475952  0.208026
# 6          0.002884  0.070698  0.025081  0.177925  0.428821  0.254304
# 7          0.003878  0.061496  0.028737  0.201782  0.422691  0.231772
# 8          0.003553  0.071076  0.025653  0.194342  0.405697  0.248021
# 9          0.002760  0.075805  0.023695  0.195857  0.446784  0.209914
# 10         0.002654  0.079027  0.020554  0.192602  0.440558  0.214173
# 11         0.002949  0.087497  0.024689  0.199653  0.443982  0.190607
# 12         0.002863  0.088974  0.024848  0.201278  0.444696  0.181039
# 13         0.002353  0.092902  0.018397  0.209136  0.458216  0.164943
# 14         0.002294  0.097080  0.021450  0.214499  0.453819  0.155802
# 15         0.001989  0.103170  0.013597  0.212393  0.455342  0.149329
# 16         0.002023  0.098710  0.017159  0.220396  0.469875  0.131568
# 17         0.002455  0.110987  0.018079  0.224095  0.466603  0.113498
# 18         0.003445  0.121016  0.004307  0.241171  0.431955  0.110250
#
# wp_type     Sniper   Unknown
# att_rank
# 1         0.006944  0.000000
# 2         0.044888  0.000000
# 3         0.009524  0.000000
# 4         0.031881  0.000000
# 5         0.038950  0.000000
# 6         0.040287  0.000000
# 7         0.049621  0.000024
# 8         0.051659  0.000000
# 9         0.045186  0.000000
# 10        0.050432  0.000000
# 11        0.050613  0.000010
# 12        0.056281  0.000021
# 13        0.054054  0.000000
# 14        0.055056  0.000000
# 15        0.064179  0.000000
# 16        0.060269  0.000000
# 17        0.064282  0.000000
# 18        0.087855  0.000000

# %%
ct = pd.crosstab(df["att_rank"], df["wp"], normalize=0)
ct
# Out:
# wp            AK47       AUG       AWP     Bizon      Bomb        CZ  \
# att_rank
# 1         0.138889  0.000000  0.006944  0.027778  0.000000  0.000000
# 2         0.259352  0.000000  0.032419  0.000000  0.000000  0.000000
# 3         0.177778  0.050794  0.007937  0.031746  0.000000  0.001587
# 4         0.208289  0.019660  0.017535  0.011158  0.000000  0.001063
# 5         0.184420  0.031278  0.023901  0.019475  0.000000  0.009737
# 6         0.201870  0.017478  0.027877  0.020100  0.000000  0.005855
# 7         0.203685  0.024762  0.037264  0.011249  0.000000  0.007828
# 8         0.206593  0.013298  0.039098  0.014301  0.000000  0.005971
# 9         0.230776  0.011087  0.034800  0.006696  0.000000  0.007716
# 10        0.224980  0.008480  0.039824  0.008583  0.000000  0.008394
# 11        0.232701  0.007403  0.040760  0.006416  0.000000  0.010571
# 12        0.244979  0.007421  0.044280  0.008073  0.000000  0.011587
# 13        0.259271  0.006023  0.044033  0.004896  0.000000  0.012444
# 14        0.256134  0.001904  0.046033  0.003748  0.000000  0.012404
# 15        0.259529  0.002383  0.051679  0.003464  0.000000  0.013494
# 16        0.263953  0.002801  0.046904  0.004027  0.000019  0.017587
# 17        0.269795  0.003013  0.052843  0.002790  0.000000  0.016684
# 18        0.301464  0.000000  0.073643  0.000000  0.000000  0.034022
#
# wp          Deagle     Decoy  DualBarettas     Famas  ...    Scar20     Scout  \
# att_rank                                              ...
# 1         0.006944  0.000000      0.000000  0.076389  ...  0.000000  0.000000
# 2         0.024938  0.000000      0.012469  0.014963  ...  0.000000  0.012469
# 3         0.023810  0.000000      0.004762  0.030159  ...  0.001587  0.000000
# 4         0.014878  0.000000      0.001063  0.020191  ...  0.000000  0.012221
# 5         0.013868  0.000000      0.001770  0.020360  ...  0.001180  0.011803
# 6         0.013283  0.000000      0.002884  0.022896  ...  0.002360  0.007778
# 7         0.019366  0.000000      0.003685  0.017849  ...  0.001710  0.008840
# 8         0.020419  0.000000      0.002845  0.017795  ...  0.002433  0.008595
# 9         0.020771  0.000018      0.002432  0.019332  ...  0.000975  0.008245
# 10        0.022760  0.000034      0.001551  0.021855  ...  0.001551  0.007773
# 11        0.023732  0.000000      0.002112  0.021311  ...  0.001225  0.007881
# 12        0.026202  0.000010      0.001809  0.020921  ...  0.001726  0.008527
# 13        0.025636  0.000010      0.001276  0.023372  ...  0.000708  0.008256
# 14        0.029195  0.000000      0.001715  0.022278  ...  0.000922  0.007816
# 15        0.028497  0.000000      0.000720  0.021176  ...  0.000617  0.011025
# 16        0.036729  0.000000      0.001420  0.022995  ...  0.001265  0.009571
# 17        0.042855  0.000000      0.000335  0.024943  ...  0.000167  0.010658
# 18        0.068475  0.000000      0.000000  0.015504  ...  0.002584  0.011628
#
# wp           Smoke     Swag7      Tec9       UMP       USP   Unknown  \
# att_rank
# 1         0.000000  0.000000  0.048611  0.013889  0.041667  0.000000
# 2         0.000000  0.000000  0.007481  0.094763  0.067332  0.000000
# 3         0.000000  0.000000  0.026984  0.025397  0.077778  0.000000
# 4         0.000000  0.003719  0.011158  0.022317  0.088204  0.000000
# 5         0.000885  0.000000  0.013278  0.058424  0.053703  0.000000
# 6         0.000437  0.003845  0.011798  0.076728  0.058813  0.000000
# 7         0.000409  0.005396  0.012622  0.060484  0.052391  0.000024
# 8         0.000545  0.007504  0.011721  0.058957  0.055227  0.000000
# 9         0.000756  0.004765  0.009474  0.070074  0.055790  0.000000
# 10        0.000465  0.005929  0.010479  0.061153  0.049708  0.000000
# 11        0.000717  0.007433  0.012733  0.065140  0.049398  0.000010
# 12        0.000806  0.007638  0.011928  0.058379  0.048239  0.000021
# 13        0.000748  0.007329  0.013810  0.052269  0.045907  0.000000
# 14        0.000899  0.004836  0.012948  0.050539  0.049344  0.000000
# 15        0.001063  0.006241  0.013649  0.050394  0.043449  0.000000
# 16        0.000681  0.005700  0.011634  0.046087  0.047196  0.000000
# 17        0.001395  0.009598  0.012890  0.044250  0.045422  0.000000
# 18        0.000000  0.000000  0.018949  0.033161  0.041344  0.000000
#
# wp          XM1014      Zeus
# att_rank
# 1         0.000000  0.000000
# 2         0.007481  0.000000
# 3         0.009524  0.000000
# 4         0.054729  0.000000
# 5         0.006197  0.000000
# 6         0.010749  0.000087
# 7         0.008118  0.000265
# 8         0.010851  0.000162
# 9         0.011187  0.000164
# 10        0.006076  0.000241
# 11        0.008299  0.000179
# 12        0.008972  0.000300
# 13        0.004976  0.000160
# 14        0.003843  0.000355
# 15        0.004064  0.000309
# 16        0.006186  0.000156
# 17        0.001507  0.000000
# 18        0.000431  0.000000
#
# [18 rows x 42 columns]

# %%
import seaborn as sns

sns.heatmap(ct, vmin=0, vmax=ct.values.max(), cmap="coolwarm")
plt.savefig("../images/03_rank_wp_heatmap.png")
plt.show()

# %%
ct = pd.crosstab(df["round_type"], df["att_rank"], normalize=1)
ct
# Out:
# att_rank            1         2         3         4         5         6   \
# round_type
# ECO           0.361111  0.314214  0.223810  0.198725  0.168486  0.179149
# FORCE_BUY     0.041667  0.142145  0.177778  0.189692  0.192387  0.194704
# NORMAL        0.430556  0.361596  0.430159  0.418172  0.483623  0.463777
# PISTOL_ROUND  0.069444  0.102244  0.084127  0.112115  0.076129  0.076641
# SEMI_ECO      0.097222  0.079800  0.084127  0.081296  0.079374  0.085729
#
# att_rank            7         8         9         10        11        12  \
# round_type
# ECO           0.204264  0.206357  0.221839  0.231538  0.258636  0.268546
# FORCE_BUY     0.176996  0.178493  0.169137  0.158579  0.150196  0.142919
# NORMAL        0.453908  0.465877  0.456413  0.463438  0.442497  0.441585
# PISTOL_ROUND  0.082235  0.079199  0.082665  0.080914  0.078739  0.076871
# SEMI_ECO      0.082597  0.070073  0.069947  0.065531  0.069932  0.070080
#
# att_rank            13        14        15        16        17        18
# round_type
# ECO           0.292814  0.302747  0.304059  0.304126  0.311199  0.276055
# FORCE_BUY     0.132507  0.125424  0.127107  0.127658  0.121310  0.167097
# NORMAL        0.432959  0.427840  0.424084  0.423886  0.414207  0.394488
# PISTOL_ROUND  0.076549  0.076848  0.077571  0.076416  0.075331  0.080103
# SEMI_ECO      0.065172  0.067140  0.067180  0.067914  0.077953  0.082257

# %%
sns.heatmap(ct, vmin=0, vmax=ct.values.max(), cmap="coolwarm")
plt.savefig("../images/03_rank_round_heatmap.png")
plt.show()

# %% [markdown]
# Now let's do some coordinate visualizations.

# %%
import matplotlib.image as mpimg

img = mpimg.imread('../images/de_mirage.png')

x_min = -3217
x_max = 1912
y_min = -3401
y_max = 1682

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_mirage", 'att_pos_x'], y=df.loc[df["map"] == "de_mirage", 'att_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_mirage_att_heatmap.png")

# %%
img = mpimg.imread('../images/de_mirage.png')

x_min = -3217
x_max = 1912
y_min = -3401
y_max = 1682

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_mirage", 'vic_pos_x'], y=df.loc[df["map"] == "de_mirage", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_mirage_vic_heatmap.png")

# %%
img = mpimg.imread('../images/de_dust2.png')

x_min = -2486
x_max = 2127
y_min = -1150
y_max = 3455

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_dust2", 'vic_pos_x'], y=df.loc[df["map"] == "de_dust2", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_dust2_vic_heatmap.png")

# %%
img = mpimg.imread('../images/de_cache.png')

x_min = -2031
x_max = 3752
y_min = -2240
y_max = 3187

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_cache", 'vic_pos_x'], y=df.loc[df["map"] == "de_cache", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_cache_vic_heatmap.png")

# %%
img = mpimg.imread('../images/de_cbble.png')

x_min = -3819
x_max = 2282
y_min = -3073
y_max = 3032

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_cbble", 'vic_pos_x'], y=df.loc[df["map"] == "de_cbble", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_cbble_vic_heatmap.png")

# %%
img = mpimg.imread('../images/de_inferno.png')

x_min = -1960
x_max = 2797
y_min = -1062
y_max = 3800

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_inferno", 'vic_pos_x'], y=df.loc[df["map"] == "de_inferno", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_inferno_vic_heatmap.png")

# %%
img = mpimg.imread('../images/de_overpass.png')

x_min = -4820
x_max = 503
y_min = -3591
y_max = 1740

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_overpass", 'vic_pos_x'], y=df.loc[df["map"] == "de_overpass", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_overpass_vic_heatmap.png")

# %%
img = mpimg.imread('../images/de_train.png')

x_min = -2436
x_max = 2262
y_min = -2469
y_max = 2447

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_train", 'vic_pos_x'], y=df.loc[df["map"] == "de_train", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
plt.savefig("../images/03_train_vic_heatmap.png")

# %%
df["att_team"].value_counts()
# Out:
# att_team
# Team 1    438639
# Team 2    426341
# Name: count, dtype: int64
