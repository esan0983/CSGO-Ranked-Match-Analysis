# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data/processed/csgo_cleaned_2.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 875112 entries, 0 to 875111
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       875112 non-null  int64
#  1   file             875112 non-null  str
#  2   map              875112 non-null  str
#  3   date             875112 non-null  str
#  4   round            875112 non-null  int64
#  5   tick             875112 non-null  int64
#  6   seconds          875112 non-null  float64
#  7   att_team         875112 non-null  str
#  8   vic_team         875112 non-null  str
#  9   att_side         875112 non-null  str
#  10  vic_side         875112 non-null  str
#  11  hp_dmg           875112 non-null  int64
#  12  arm_dmg          875112 non-null  int64
#  13  is_bomb_planted  875112 non-null  bool
#  14  bomb_site        135616 non-null  str
#  15  hitbox           875112 non-null  str
#  16  wp               875112 non-null  str
#  17  wp_type          875112 non-null  str
#  18  award            875112 non-null  int64
#  19  winner_team      875112 non-null  str
#  20  winner_side      875112 non-null  str
#  21  att_id           875112 non-null  int64
#  22  att_rank         875112 non-null  int64
#  23  vic_id           875112 non-null  int64
#  24  vic_rank         875112 non-null  int64
#  25  att_pos_x        875112 non-null  float64
#  26  att_pos_y        875112 non-null  float64
#  27  vic_pos_x        875112 non-null  float64
#  28  vic_pos_y        875112 non-null  float64
#  29  round_type       875112 non-null  str
#  30  ct_eq_val        875112 non-null  int64
#  31  t_eq_val         875112 non-null  int64
#  32  avg_match_rank   875112 non-null  float64
#  33  map_1            875112 non-null  str
#  34  EndX             875112 non-null  int64
#  35  EndY             875112 non-null  int64
#  36  ResX             875112 non-null  int64
#  37  ResY             875112 non-null  int64
#  38  StartX           875112 non-null  int64
#  39  StartY           875112 non-null  int64
# dtypes: bool(1), float64(6), int64(18), str(15)
# memory usage: 261.2 MB

# %%
df["map"].value_counts().plot(kind="bar")
plt.title('Map Counts')
plt.xlabel('Map')
plt.ylabel('Count')
plt.show()

# %%
round_counts = df["round"].value_counts()
round_counts.sort_index().plot(kind='bar')
plt.xlabel('Round')
plt.ylabel('Counts')
plt.title('Round Counts')
plt.show()

# %%
plt.boxplot(df["tick"])
plt.title("Ticks")
plt.show()

# %%
plt.boxplot(df["seconds"])
plt.title("Seconds")
plt.show()

# %%
plt.boxplot(df["arm_dmg"])
plt.title("Armor Damage")
plt.show()

# %%
plt.boxplot(df["hp_dmg"])
plt.title("HP Damage")
plt.show()

# %%
df["is_bomb_planted"].value_counts().plot(kind="bar")
plt.title('Is bomb planted?')
plt.xlabel('True/False')
plt.ylabel('Count')
plt.show()

# %%
temp_df = df.loc[df["is_bomb_planted"] == True, "bomb_site"]
temp_df.value_counts().plot(kind="bar")
plt.title('Bomb Site Counts')
plt.xlabel('Bomb Site')
plt.ylabel('Count')
plt.show()

# %%
df["hitbox"].value_counts().plot(kind="bar")
plt.title('Hitbox Counts')
plt.xlabel('Hitbox')
plt.ylabel('Count')
plt.show()

# %%
df["wp"].value_counts().plot(kind="bar")
plt.title('Weapon Counts')
plt.xlabel('Weapon')
plt.ylabel('Count')
plt.show()

# %%
df["wp_type"].value_counts().plot(kind="bar")
plt.title('Weapon Type Counts')
plt.xlabel('Weapon Type')
plt.ylabel('Count')
plt.show()

# %%
att_rank_counts = df["att_rank"].value_counts()
att_rank_counts.sort_index().plot(kind='bar')
plt.xlabel('Attacker Rank')
plt.ylabel('Counts')
plt.title('Attacker Rank Counts')
plt.show()

# %%
vic_rank_counts = df["vic_rank"].value_counts()
vic_rank_counts.sort_index().plot(kind='bar')
plt.xlabel('Victim Rank')
plt.ylabel('Counts')
plt.title('Victim Rank Counts')
plt.show()

# %%
df["round_type"].value_counts().plot(kind="bar")
plt.title('Round Type Counts')
plt.xlabel('Round Type')
plt.ylabel('Count')
plt.show()

# %%
avg_rank_counts = df["avg_match_rank"].value_counts()
avg_rank_counts.sort_index().plot(kind='bar')
plt.xlabel('Average Match Rank')
plt.ylabel('Counts')
plt.title('Average Match Rank Counts')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 875112 entries, 0 to 875111
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       875112 non-null  int64
#  1   file             875112 non-null  str
#  2   map              875112 non-null  str
#  3   date             875112 non-null  str
#  4   round            875112 non-null  int64
#  5   tick             875112 non-null  int64
#  6   seconds          875112 non-null  float64
#  7   att_team         875112 non-null  str
#  8   vic_team         875112 non-null  str
#  9   att_side         875112 non-null  str
#  10  vic_side         875112 non-null  str
#  11  hp_dmg           875112 non-null  int64
#  12  arm_dmg          875112 non-null  int64
#  13  is_bomb_planted  875112 non-null  bool
#  14  bomb_site        135616 non-null  str
#  15  hitbox           875112 non-null  str
#  16  wp               875112 non-null  str
#  17  wp_type          875112 non-null  str
#  18  award            875112 non-null  int64
#  19  winner_team      875112 non-null  str
#  20  winner_side      875112 non-null  str
#  21  att_id           875112 non-null  int64
#  22  att_rank         875112 non-null  int64
#  23  vic_id           875112 non-null  int64
#  24  vic_rank         875112 non-null  int64
#  25  att_pos_x        875112 non-null  float64
#  26  att_pos_y        875112 non-null  float64
#  27  vic_pos_x        875112 non-null  float64
#  28  vic_pos_y        875112 non-null  float64
#  29  round_type       875112 non-null  str
#  30  ct_eq_val        875112 non-null  int64
#  31  t_eq_val         875112 non-null  int64
#  32  avg_match_rank   875112 non-null  float64
#  33  map_1            875112 non-null  str
#  34  EndX             875112 non-null  int64
#  35  EndY             875112 non-null  int64
#  36  ResX             875112 non-null  int64
#  37  ResY             875112 non-null  int64
#  38  StartX           875112 non-null  int64
#  39  StartY           875112 non-null  int64
# dtypes: bool(1), float64(6), int64(18), str(15)
# memory usage: 261.2 MB

# %%
plt.hist(df.loc[df["wp_type"] == "Rifle", "hp_dmg"])
plt.xlabel('HP Damage')
plt.ylabel('Counts')
plt.title('HP Damage Counts (Rifle)')
plt.show()

# %% [markdown]
# I think it's better if we do total damage in notebook 4 instead.

# %%
pd.crosstab(df["is_bomb_planted"], df["vic_side"], normalize=1)
# Out:
# vic_side         CounterTerrorist  Terrorist
# is_bomb_planted
# False                    0.824759   0.863529
# True                     0.175241   0.136471

# %%
pd.crosstab(df["is_bomb_planted"], df["winner_side"], normalize=1)
# Out:
# winner_side      CounterTerrorist  Terrorist
# is_bomb_planted
# False                    0.917846   0.777021
# True                     0.082154   0.222979

# %%
pd.crosstab(df["hitbox"], df["wp_type"], normalize=1)
# Out:
# wp_type   Equipment  Grenade     Heavy    Pistol     Rifle       SMG  \
# hitbox
# Chest           0.0      0.0  0.432170  0.478759  0.419983  0.422695
# Generic         1.0      1.0  0.000000  0.000174  0.000051  0.000097
# Head            0.0      0.0  0.106449  0.186943  0.117409  0.108471
# LeftArm         0.0      0.0  0.035117  0.026574  0.030589  0.032972
# LeftLeg         0.0      0.0  0.048495  0.030678  0.049634  0.055592
# RightArm        0.0      0.0  0.085964  0.076165  0.079123  0.077636
# 1         0.000000  0.000000
# 2         0.007481  0.000000
# 3         0.009524  0.000000
# 4         0.054729  0.000000
# 5         0.006197  0.000000
# 6         0.012201  0.000087
# 7         0.008444  0.000263
# 8         0.010701  0.000159
# 9         0.011122  0.000163
# 10        0.006006  0.000238
# 11        0.008205  0.000197
# 12        0.009067  0.000297
# 13        0.004978  0.000158
# 14        0.003778  0.000372
# 15        0.004102  0.000306
# 16        0.006097  0.000249
# 17        0.001479  0.000000
# 18        0.000431  0.000000
#
# [18 rows x 42 columns]

# %%
import seaborn as sns

sns.heatmap(ct, vmin=0, vmax=ct.values.max(), cmap="coolwarm")
plt.show()

# %%
ct = pd.crosstab(df["round_type"], df["att_rank"], normalize=1)
ct
# Out:
# att_rank            1         2         3         4         5         6   \
# round_type
# ECO           0.361111  0.314214  0.223810  0.198725  0.168486  0.179041
# FORCE_BUY     0.041667  0.142145  0.177778  0.189692  0.192387  0.197127
# NORMAL        0.430556  0.361596  0.430159  0.418172  0.483623  0.462011
# PISTOL_ROUND  0.069444  0.102244  0.084127  0.112115  0.076129  0.075891
# SEMI_ECO      0.097222  0.079800  0.084127  0.081296  0.079374  0.085929
#
# att_rank            7         8         9         10        11        12  \
# round_type
# ECO           0.203894  0.206232  0.221538  0.231721  0.258608  0.268391
# FORCE_BUY     0.177558  0.178479  0.169460  0.158293  0.150491  0.143119
# NORMAL        0.453906  0.465737  0.456980  0.463510  0.442568  0.441523
# PISTOL_ROUND  0.081974  0.078908  0.082516  0.080851  0.078747  0.076909
# SEMI_ECO      0.082668  0.070644  0.069506  0.065624  0.069587  0.070057
#
# att_rank            13        14        15        16        17        18
# round_type
# ECO           0.292947  0.302335  0.304397  0.304352  0.310638  0.276055
# FORCE_BUY     0.132833  0.125484  0.127492  0.127550  0.121111  0.167097
# NORMAL        0.432556  0.428366  0.423667  0.422719  0.414165  0.394488
# PISTOL_ROUND  0.076600  0.076662  0.077584  0.076706  0.075372  0.080103
# SEMI_ECO      0.065063  0.067153  0.066861  0.068673  0.078714  0.082257

# %%
sns.heatmap(ct, vmin=0, vmax=ct.values.max(), cmap="coolwarm")
plt.show()

# %% [markdown]
# Now let's do some coordinate visualizations.

# %%
import matplotlib.image as mpimg

img = mpimg.imread('../images/de_mirage.png')

x_min = -3217
x_max = 1912
y_min = -3401
y_max = 1682

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_mirage", 'att_pos_x'], y=df.loc[df["map"] == "de_mirage", 'att_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
# Out:
# (-3401.0, 1682.0)

# %%
img = mpimg.imread('../images/de_mirage.png')

x_min = -3217
x_max = 1912
y_min = -3401
y_max = 1682

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_mirage", 'vic_pos_x'], y=df.loc[df["map"] == "de_mirage", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
# Out:
# (-3401.0, 1682.0)

# %%
img = mpimg.imread('../images/de_dust2.png')

x_min = -2486
x_max = 2127
y_min = -1150
y_max = 3455

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img, extent=[x_min, x_max, y_min, y_max])  # your map's start/end coords
sns.kdeplot(x=df.loc[df["map"] == "de_dust2", 'vic_pos_x'], y=df.loc[df["map"] == "de_dust2", 'vic_pos_y'], ax=ax, cmap='inferno', fill=True, alpha=0.5, levels=50)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
# Out:
# (-1150.0, 3455.0)
